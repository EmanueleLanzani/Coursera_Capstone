# %% [markdown]
# # This notebook is the code which will cover the data extraction and manipulation for the capstone

# %%
print('importation: begin!')
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import re

import numpy as np # library to handle data in a vectorized manner

import json # library to handle JSON files

from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# !pip install folium # -c conda-forge folium=0.5.0 --yes
import folium # map rendering library

print('Libraries imported.')
# Out:
# importation: begin!
# Requirement already satisfied: folium in /opt/conda/envs/Python36/lib/python3.6/site-packages (0.11.0)
# Requirement already satisfied: branca>=0.3.0 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (0.4.1)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.21.0)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (2.10)
# Requirement already satisfied: numpy in /opt/conda/envs/Python36/lib/python3.6/site-packages (from folium) (1.15.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2020.4.5.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->folium) (2.8)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from jinja2>=2.9->folium) (1.1.0)
# Libraries imported.

# %% [markdown]
# **The cell below extracts data about Italy's provinces, from a wikipedia page. Since some cities are displayed with the english name, we need to use the equivalent italian wikipedia page, which uses approximately the same names as the infected spreadsheet**

# %%
url = 'https://it.wikipedia.org/wiki/Province_d%27Italia'

df = pd.read_html(url)

# %% [markdown]
# **Since there are more than one data frame in that page, we will need to look into them, to find out which one we're interested in.**
#
# It turns out we care about the fist one, so position 0 in the list of dataframes.

# %%
# There are 11 elements in df, which means 11 different dataframes! We care about the fisrt one, position number 0
for i in range(len(df)):
    print('new dataframe\n')
    df_new = df[i]
    print(df_new.head(2))
# Out:
# new dataframe
#
#                      Provincia Sigla   Regione Popolazione(ab.)  \
# 0  Agrigento (lib. cons. com.)    AG   Sicilia          434 870
# 1                  Alessandria    AL  Piemonte          421 284
#
#   Superficie(km²) Densità(ab./km²) Comuni(N°)          Presidente  \
# 0        3 052,59              142         43  Roberto Barberi[6]
# 1        3 558,83              118        187    Gianfranco Baldi
#
#                         Partito
# 0     Commissario straordinario
# 1  Indipendente (Centro-destra)
# new dataframe
#
#    Pos.    Provincia Sigla              Regione  Superficie (km²)
# 0     1      Sassari    SS             Sardegna           7692090
# 1     2  Bolzano[21]    BZ  Trentino-Alto Adige           7398381
# new dataframe
#
#   V · D · M Suddivisioni dell'Italia  \
# 0                Regioni statistiche
# 1                            Regioni
#
#                 V · D · M Suddivisioni dell'Italia.1
# 0  RegioniProvince, province autonome, città metr...
# 1  Province, province autonome, città metropolita...
# new dataframe
#
#          0                                                  1
# 0  Regioni  Province, province autonome, città metropolita...
# new dataframe
#
#                0                                                  1
# 0       Piemonte  Alessandria · Asti · Biella · Cuneo · Novara ·...
# 1  Valle d'Aosta                                            nessuna
# new dataframe
#
#                      0                                                  1
# 0  Trentino-Alto Adige                                   Bolzano · Trento
# 1               Veneto  Belluno · Padova · Rovigo · Treviso · Venezia ...
# new dataframe
#
#          0                                                  1
# 0  Toscana  Arezzo · Firenze · Grosseto · Livorno · Lucca ...
# 1   Umbria                                    Perugia · Terni
# new dataframe
#
#          0                                     1
# 0  Abruzzo  Chieti · L'Aquila · Pescara · Teramo
# 1   Molise                  Campobasso · Isernia
# new dataframe
#
#           0                                                  1
# 0   Sicilia  Agrigento · Caltanissetta · Catania · Enna · M...
# 1  Sardegna  Cagliari · Nuoro · Oristano · Sassari · Sud Sa...
# new dataframe
#
#   V · D · MSuddivisioni territoriali degli stati d'Europa  \
# 0                                           Stati UE
# 1                                     Stati extra UE
#
#   V · D · MSuddivisioni territoriali degli stati d'Europa.1
# 0  Belgio: Comunità · Regioni · Province · Arrond...
# 1  Albania: Prefetture · Distretti · Comuni • Mac...
# new dataframe
#
#   V · D · M Repubblica Italiana  \
# 0       Organizzazione generale
# 1         Organi costituzionali
#
#                      V · D · M Repubblica Italiana.1  \
# 0  Costituzione della Repubblica Italiana · Siste...
# 1  Parlamento (regolamenti) · Senato della Repubb...
#
#    V · D · M Repubblica Italiana.2
# 0                              NaN
# 1                              NaN
# new dataframe
#
#                        0                     1
# 0  Controllo di autorità  LCCN (EN) sh00002373
# new dataframe
#
#                  0                 1                        2
# 0  Portale Diritto  Portale Politica  Portale Storia d'Italia

# %%
# we extract the relevant table by accessing index two of the list
df1 = df[0]
df1.head()
# Out:
#                      Provincia Sigla        Regione Popolazione(ab.)  \
# 0  Agrigento (lib. cons. com.)    AG        Sicilia          434 870
# 1                  Alessandria    AL       Piemonte          421 284
# 2                       Ancona    AN         Marche          471 228
# 3      Aosta[7] (reg.autonoma)    AO  Valle d'Aosta          125 666
# 4                       Arezzo    AR        Toscana          342 654
#
#   Superficie(km²) Densità(ab./km²) Comuni(N°)          Presidente  \
# 0        3 052,59              142         43  Roberto Barberi[6]
# 1        3 558,83              118        187    Gianfranco Baldi
# 2        1 936,22              240         47       Luigi Cerioni
# 3         3 260,9               39         74                   /
# 4        3 233,08              106         36     Silvia Chiassai
#
#                           Partito
# 0       Commissario straordinario
# 1    Indipendente (Centro-destra)
# 2  Indipendente (Centro-sinistra)
# 3                               /
# 4    Indipendente (Centro-destra)

# %% [markdown]
# **We can drop a few columns, since we're not really interested in many of them**

# %%
df2 = df1.drop(axis= 1, columns = ['Sigla', 'Regione', 'Superficie(km²)', 'Comuni(N°)', 'Partito', 'Presidente'])

# %% [markdown]
# **We then rename some columns to better fit our needs, using the english equivalent**

# %%
df2.rename(columns = {'Provincia':'Province','Popolazione(ab.)':'Population', 'Densità(ab./km²)':'Density'}, inplace = True)

# %%
df2.head(15)
# Out:
#                        Province Population Density
# 0   Agrigento (lib. cons. com.)    434 870     142
# 1                   Alessandria    421 284     118
# 2                        Ancona    471 228     240
# 3       Aosta[7] (reg.autonoma)    125 666      39
# 4                        Arezzo    342 654     106
# 5                 Ascoli Piceno    207 179     169
# 6                          Asti    214 638     142
# 7                      Avellino    418 306     149
# 8                          Bari  1 248 489     326
# 9         Barletta-Andria-Trani    390 011     253
# 10  Belluno (provincia montana)    202 950      56
# 11                    Benevento    277 018     133
# 12                      Bergamo  1 114 590     405
# 13                       Biella    177 585     192
# 14                      Bologna  1 017 196     274

# %% [markdown]
# **As we can see, there is some data cleaning to do on this table. Let's proceed with cleaning up the names. We can see there are many unnecessary brackets information that we need to take out**

# %%
regespr = re.compile(r' \(')
regespr1 = re.compile(r'\[')

new_list = list()
for i in df2['Province']:
    #print(i)
    try:
        start_pos = re.search(regespr, i).start()
        new_i = i[:start_pos]
    except:
        start_pos = 0
        new_i = i
    try:
        start_pos1 = re.search(regespr1, new_i).start()
        new_i1 = new_i[:start_pos1]
    except:
        start_pos1 = 0
        new_i1 = new_i
    lower_item = new_i1.lower()
    new_list.append(lower_item)

# %% [markdown]
# **There are still some unique records that don't match. We will replace them manually**

# %%
print(new_list)
for count,i in enumerate(new_list):
    if i == 'forlì-cesena':
        new_list[count] = 'forlì cesena'
    if i == 'massa-carrara':
        new_list[count] = 'massa carrara' #
    if i == 'monza e brianza':
        new_list[count] = 'monza brianza'
    if i == 'pesaro e urbino':
        new_list[count] = 'pesaro'
print(new_list)

df2['Province adjusted'] = np.array(new_list) # adds column with new list to dataframe
df2.head()
# Out:
# ['agrigento', 'alessandria', 'ancona', 'aosta', 'arezzo', 'ascoli piceno', 'asti', 'avellino', 'bari', 'barletta-andria-trani', 'belluno', 'benevento', 'bergamo', 'biella', 'bologna', 'bolzano', 'brescia', 'brindisi', 'cagliari', 'caltanissetta', 'campobasso', 'caserta', 'catania', 'catanzaro', 'chieti', 'como', 'cosenza', 'cremona', 'crotone', 'cuneo', 'enna', 'fermo', 'ferrara', 'firenze', 'foggia', 'forlì-cesena', 'frosinone', 'genova', 'gorizia', 'grosseto', 'imperia', 'isernia', "l'aquila", 'la spezia', 'latina', 'lecce', 'lecco', 'livorno', 'lodi', 'lucca', 'macerata', 'mantova', 'massa-carrara', 'matera', 'messina', 'milano', 'modena', 'monza e brianza', 'napoli', 'novara', 'nuoro', 'oristano', 'palermo', 'padova', 'parma', 'pavia', 'perugia', 'pesaro e urbino', 'pescara', 'piacenza', 'pisa', 'pistoia', 'pordenone', 'potenza', 'prato', 'reggio calabria', 'ragusa', 'ravenna', 'reggio emilia', 'rieti', 'rimini', 'roma', 'rovigo', 'salerno', 'sassari', 'savona', 'siena', 'siracusa', 'sondrio', 'sud sardegna', 'taranto', 'teramo', 'terni', 'torino', 'trapani', 'trento', 'treviso', 'trieste', 'udine', 'varese', 'venezia', 'verbano-cusio-ossola', 'vercelli', 'verona', 'vibo valentia', 'vicenza', 'viterbo', 'totale']
# ['agrigento', 'alessandria', 'ancona', 'aosta', 'arezzo', 'ascoli piceno', 'asti', 'avellino', 'bari', 'barletta-andria-trani', 'belluno', 'benevento', 'bergamo', 'biella', 'bologna', 'bolzano', 'brescia', 'brindisi', 'cagliari', 'caltanissetta', 'campobasso', 'caserta', 'catania', 'catanzaro', 'chieti', 'como', 'cosenza', 'cremona', 'crotone', 'cuneo', 'enna', 'fermo', 'ferrara', 'firenze', 'foggia', 'forlì cesena', 'frosinone', 'genova', 'gorizia', 'grosseto', 'imperia', 'isernia', "l'aquila", 'la spezia', 'latina', 'lecce', 'lecco', 'livorno', 'lodi', 'lucca', 'macerata', 'mantova', 'massa carrara', 'matera', 'messina', 'milano', 'modena', 'monza brianza', 'napoli', 'novara', 'nuoro', 'oristano', 'palermo', 'padova', 'parma', 'pavia', 'perugia', 'pesaro', 'pescara', 'piacenza', 'pisa', 'pistoia', 'pordenone', 'potenza', 'prato', 'reggio calabria', 'ragusa', 'ravenna', 'reggio emilia', 'rieti', 'rimini', 'roma', 'rovigo', 'salerno', 'sassari', 'savona', 'siena', 'siracusa', 'sondrio', 'sud sardegna', 'taranto', 'teramo', 'terni', 'torino', 'trapani', 'trento', 'treviso', 'trieste', 'udine', 'varese', 'venezia', 'verbano-cusio-ossola', 'vercelli', 'verona', 'vibo valentia', 'vicenza', 'viterbo', 'totale']
#                       Province Population Density Province adjusted
# 0  Agrigento (lib. cons. com.)    434 870     142         agrigento
# 1                  Alessandria    421 284     118       alessandria
# 2                       Ancona    471 228     240            ancona
# 3      Aosta[7] (reg.autonoma)    125 666      39             aosta
# 4                       Arezzo    342 654     106            arezzo

# %% [markdown]
# **We will then drop the first province column and then rename the new one to the old one**

# %%
df3 = df2.drop(axis= 1, columns = ['Province'])
df3.rename(columns = {'Province adjusted':'Province'}, inplace = True)
df3.head(150)
# Out:
#      Population Density               Province
# 0       434 870     142              agrigento
# 1       421 284     118            alessandria
# 2       471 228     240                 ancona
# 3       125 666      39                  aosta
# 4       342 654     106                 arezzo
# 5       207 179     169          ascoli piceno
# 6       214 638     142                   asti
# 7       418 306     149               avellino
# 8     1 248 489     326                   bari
# 9       390 011     253  barletta-andria-trani
# 10      202 950      56                belluno
# 11      277 018     133              benevento
# 12    1 114 590     405                bergamo
# 13      177 585     192                 biella
# 14    1 017 196     274                bologna
# 15      531 178      72                bolzano
# 16    1 265 954     265                brescia
# 17      392 975     211               brindisi
# 18      430 372     344               cagliari
# 19      262 458     123          caltanissetta
# 20      221 238      76             campobasso
# 21      922 965     348                caserta
# 22    1 103 917     310                catania
# 23      358 316     148              catanzaro
# 24      385 588     148                 chieti
# 25      599 204     468                   como
# 26      705 753     105                cosenza
# 27      358 955     203                cremona
# 28      174 980     101                crotone
# 29      587 098      85                  cuneo
# 30      164 788      64                   enna
# 31      173 800     201                  fermo
# 32      345 691     131                ferrara
# 33    1 012 407     288                firenze
# 34      622 183      89                 foggia
# 35      394 627     166           forlì cesena
# 36      489 083     151              frosinone
# 37      837 427     455                 genova
# 38      139 403     298                gorizia
# 39      221 629      49               grosseto
# 40      213 840     185                imperia
# 41       84 379      55                isernia
# 42      299 031      59               l'aquila
# 43      219 556     249              la spezia
# 44      575 254     255                 latina
# 45      795 134     284                  lecce
# 46      337 380     419                  lecco
# 47      334 832     276                livorno
# 48      230 198     294                   lodi
# 49      387 876     219                  lucca
# 50      314 178     113               macerata
# 51      412 292     176                mantova
# 52      194 878     169          massa carrara
# 53      197 909      57                 matera
# 54      622 962     191                messina
# 55    3 261 873   2 071                 milano
# 56      705 393     262                 modena
# 57      873 935    2156          monza brianza
# 58    3 072 996   2 624                 napoli
# 59      369 018     275                 novara
# 60      208 550      37                  nuoro
# 61      157 707      53               oristano
# 62    1 245 826     249                palermo
# 63      937 908     437                 padova
# 64      451 631     131                  parma
# 65      545 888     184                  pavia
# 66      656 382     104                perugia
# 67      358 886     140                 pesaro
# 68      318 909     259                pescara
# 69      287 674     111               piacenza
# 70      419 037     171                   pisa
# 71      292 473     303                pistoia
# 72      312 533     137              pordenone
# 73      364 960      55                potenza
# 74      257 716     705                  prato
# 75      544 815     171        reggio calabria
# 76      320 893     198                 ragusa
# 77      389 456     209                ravenna
# 78      531 891     232          reggio emilia
# 79      155 503      57                  rieti
# 80      339 017     392                 rimini
# 81    4 335 849     810                   roma
# 82      234 937     129                 rovigo
# 83    1 098 513     222                salerno
# 84      491 571      64                sassari
# 85      276 064     179                 savona
# 86      267 197      70                  siena
# 87      399 224     188               siracusa
# 88      181 095      57                sondrio
# 89      350 725      54           sud sardegna
# 90      576 756     234                taranto
# 91      308 052     158                 teramo
# 92      225 633     106                  terni
# 93    2 256 142     330                 torino
# 94      430 492     174                trapani
# 95      541 098      87                 trento
# 96      887 806     358                treviso
# 97      234 493    1103                trieste
# 98      528 791     106                  udine
# 99      890 768     743                 varese
# 100     852 351     346                venezia
# 101     157 844      70   verbano-cusio-ossola
# 102     170 911      82               vercelli
# 103     926 497     299                 verona
# 104     160 073     139          vibo valentia
# 105     862 418     317                vicenza
# 106     317 030      88                viterbo
# 107  60 359 546   19982                 totale

# %% [markdown]
# **Now we need to delete those annoying spaces between numbers in the population column**

# %%
#regespr2 = re.compile(r' ')

new_list1 = list()
for i in df3['Population']:
    new_list1.append(i)
print(new_list1)
new_list2 = list()
for i in new_list1:
    #print(i)
    #print(len(i))
    if len(i) > 3:
        new_i = i[:-4]+i[-3:]
    else:
        new_i = i
    print(new_i)
    if len(new_i) > 6:
        new_i = new_i[:-7]+new_i[-6:]
    else:
        new_i = new_i
    new_i = int(new_i)
    new_list2.append(new_i)
print(new_list2)
# Out:
# ['434\xa0870', '421\xa0284', '471\xa0228', '125\xa0666', '342\xa0654', '207\xa0179', '214\xa0638', '418\xa0306', '1\xa0248\xa0489', '390\xa0011', '202\xa0950', '277\xa0018', '1\xa0114\xa0590', '177\xa0585', '1\xa0017\xa0196', '531\xa0178', '1\xa0265\xa0954', '392\xa0975', '430\xa0372', '262\xa0458', '221\xa0238', '922\xa0965', '1\xa0103\xa0917', '358\xa0316', '385\xa0588', '599\xa0204', '705\xa0753', '358\xa0955', '174\xa0980', '587\xa0098', '164\xa0788', '173\xa0800', '345\xa0691', '1\xa0012\xa0407', '622\xa0183', '394\xa0627', '489\xa0083', '837\xa0427', '139\xa0403', '221\xa0629', '213\xa0840', '84\xa0379', '299\xa0031', '219\xa0556', '575\xa0254', '795\xa0134', '337\xa0380', '334\xa0832', '230\xa0198', '387\xa0876', '314\xa0178', '412\xa0292', '194\xa0878', '197\xa0909', '622\xa0962', '3\xa0261\xa0873', '705\xa0393', '873\xa0935', '3\xa0072\xa0996', '369\xa0018', '208\xa0550', '157\xa0707', '1\xa0245\xa0826', '937\xa0908', '451\xa0631', '545\xa0888', '656\xa0382', '358\xa0886', '318\xa0909', '287 674', '419\xa0037', '292\xa0473', '312\xa0533', '364\xa0960', '257\xa0716', '544\xa0815', '320\xa0893', '389\xa0456', '531\xa0891', '155\xa0503', '339\xa0017', '4\xa0335\xa0849', '234\xa0937', '1\xa0098\xa0513', '491\xa0571', '276\xa0064', '267\xa0197', '399\xa0224', '181\xa0095', '350\xa0725', '576\xa0756', '308\xa0052', '225\xa0633', '2\xa0256\xa0142', '430\xa0492', '541\xa0098', '887\xa0806', '234\xa0493', '528\xa0791', '890\xa0768', '852\xa0351', '157\xa0844', '170\xa0911', '926\xa0497', '160\xa0073', '862\xa0418', '317\xa0030', '60 359 546']
# 434870
# 421284
# 471228
# 125666
# 342654
# 207179
# 214638
# 418306
# 1 248489
# 390011
# 202950
# 277018
# 1 114590
# 177585
# 1 017196
# 531178
# 1 265954
# 392975
# 430372
# 262458
# 221238
# 922965
# 1 103917
# 358316
# 385588
# 599204
# 705753
# 358955
# 174980
# 587098
# 164788
# 173800
# 345691
# 1 012407
# 622183
# 394627
# 489083
# 837427
# 139403
# 221629
# 213840
# 84379
# 299031
# 219556
# 575254
# 795134
# 337380
# 334832
# 230198
# 387876
# 314178
# 412292
# 194878
# 197909
# 622962
# 3 261873
# 705393
# 873935
# 3 072996
# 369018
# 208550
# 157707
# 1 245826
# 937908
# 451631
# 545888
# 656382
# 358886
# 318909
# 287674
# 419037
# 292473
# 312533
# 364960
# 257716
# 544815
# 320893
# 389456
# 531891
# 155503
# 339017
# 4 335849
# 234937
# 1 098513
# 491571
# 276064
# 267197
# 399224
# 181095
# 350725
# 576756
# 308052
# 225633
# 2 256142
# 430492
# 541098
# 887806
# 234493
# 528791
# 890768
# 852351
# 157844
# 170911
# 926497
# 160073
# 862418
# 317030
# 60 359546
# [434870, 421284, 471228, 125666, 342654, 207179, 214638, 418306, 1248489, 390011, 202950, 277018, 1114590, 177585, 1017196, 531178, 1265954, 392975, 430372, 262458, 221238, 922965, 1103917, 358316, 385588, 599204, 705753, 358955, 174980, 587098, 164788, 173800, 345691, 1012407, 622183, 394627, 489083, 837427, 139403, 221629, 213840, 84379, 299031, 219556, 575254, 795134, 337380, 334832, 230198, 387876, 314178, 412292, 194878, 197909, 622962, 3261873, 705393, 873935, 3072996, 369018, 208550, 157707, 1245826, 937908, 451631, 545888, 656382, 358886, 318909, 287674, 419037, 292473, 312533, 364960, 257716, 544815, 320893, 389456, 531891, 155503, 339017, 4335849, 234937, 1098513, 491571, 276064, 267197, 399224, 181095, 350725, 576756, 308052, 225633, 2256142, 430492, 541098, 887806, 234493, 528791, 890768, 852351, 157844, 170911, 926497, 160073, 862418, 317030, 60359546]

# %%
df3['Population adjusted'] = np.array(new_list2) # adds column with new list to dataframe
df4 = df3.drop(axis= 1, columns = ['Population'])
df4.rename(columns = {'Population adjusted':'Population'}, inplace = True)
df4.head(150)
# Out:
#     Density               Province  Population
# 0       142              agrigento      434870
# 1       118            alessandria      421284
# 2       240                 ancona      471228
# 3        39                  aosta      125666
# 4       106                 arezzo      342654
# 5       169          ascoli piceno      207179
# 6       142                   asti      214638
# 7       149               avellino      418306
# 8       326                   bari     1248489
# 9       253  barletta-andria-trani      390011
# 10       56                belluno      202950
# 11      133              benevento      277018
# 12      405                bergamo     1114590
# 13      192                 biella      177585
# 14      274                bologna     1017196
# 15       72                bolzano      531178
# 16      265                brescia     1265954
# 17      211               brindisi      392975
# 18      344               cagliari      430372
# 19      123          caltanissetta      262458
# 20       76             campobasso      221238
# 21      348                caserta      922965
# 22      310                catania     1103917
# 23      148              catanzaro      358316
# 24      148                 chieti      385588
# 25      468                   como      599204
# 26      105                cosenza      705753
# 27      203                cremona      358955
# 28      101                crotone      174980
# 29       85                  cuneo      587098
# 30       64                   enna      164788
# 31      201                  fermo      173800
# 32      131                ferrara      345691
# 33      288                firenze     1012407
# 34       89                 foggia      622183
# 35      166           forlì cesena      394627
# 36      151              frosinone      489083
# 37      455                 genova      837427
# 38      298                gorizia      139403
# 39       49               grosseto      221629
# 40      185                imperia      213840
# 41       55                isernia       84379
# 42       59               l'aquila      299031
# 43      249              la spezia      219556
# 44      255                 latina      575254
# 45      284                  lecce      795134
# 46      419                  lecco      337380
# 47      276                livorno      334832
# 48      294                   lodi      230198
# 49      219                  lucca      387876
# 50      113               macerata      314178
# 51      176                mantova      412292
# 52      169          massa carrara      194878
# 53       57                 matera      197909
# 54      191                messina      622962
# 55    2 071                 milano     3261873
# 56      262                 modena      705393
# 57     2156          monza brianza      873935
# 58    2 624                 napoli     3072996
# 59      275                 novara      369018
# 60       37                  nuoro      208550
# 61       53               oristano      157707
# 62      249                palermo     1245826
# 63      437                 padova      937908
# 64      131                  parma      451631
# 65      184                  pavia      545888
# 66      104                perugia      656382
# 67      140                 pesaro      358886
# 68      259                pescara      318909
# 69      111               piacenza      287674
# 70      171                   pisa      419037
# 71      303                pistoia      292473
# 72      137              pordenone      312533
# 73       55                potenza      364960
# 74      705                  prato      257716
# 75      171        reggio calabria      544815
# 76      198                 ragusa      320893
# 77      209                ravenna      389456
# 78      232          reggio emilia      531891
# 79       57                  rieti      155503
# 80      392                 rimini      339017
# 81      810                   roma     4335849
# 82      129                 rovigo      234937
# 83      222                salerno     1098513
# 84       64                sassari      491571
# 85      179                 savona      276064
# 86       70                  siena      267197
# 87      188               siracusa      399224
# 88       57                sondrio      181095
# 89       54           sud sardegna      350725
# 90      234                taranto      576756
# 91      158                 teramo      308052
# 92      106                  terni      225633
# 93      330                 torino     2256142
# 94      174                trapani      430492
# 95       87                 trento      541098
# 96      358                treviso      887806
# 97     1103                trieste      234493
# 98      106                  udine      528791
# 99      743                 varese      890768
# 100     346                venezia      852351
# 101      70   verbano-cusio-ossola      157844
# 102      82               vercelli      170911
# 103     299                 verona      926497
# 104     139          vibo valentia      160073
# 105     317                vicenza      862418
# 106      88                viterbo      317030
# 107   19982                 totale    60359546

# %% [markdown]
# ### Now, we proceed to wrangle the second data source: Since it is a pdf file (http://www.salute.gov.it/imgs/C_17_notizie_4702_1_file.pdf), there are a couple of python packages that allow to wrangle pdf files: tabula and camelot. Of course, none of them is working in this jupiter environment. Even though they get installed with the !pip command, they throw different traceback errors when trying to parse the file. So i had to download it, convert to csv file, and then upload it in my github page. Not ideal, but i have currently no other way to get around the problem.

# %%
csv_file = 'https://github.com/EmanueleLanzani/Coursera_Capstone/blob/master/infected_situation_7_may.csv'
inf_df = pd.read_html(csv_file)

# %%
inf_df1 = inf_df[0]

# %%
inf_df1.head(5)
# Out:
#    Unnamed: 0     Province  Infected
# 0         NaN    agrigento       135
# 1         NaN  alessandria      3654
# 2         NaN       ancona      1822
# 3         NaN        aosta      1150
# 4         NaN       arezzo       655

# %%
#The first column is clearly a parsing error, so we proceed to drop it:

inf_df2 = inf_df1.drop(axis= 1, columns = ['Unnamed: 0'])
inf_df2.head(150)
# Out:
#                  Province  Infected
# 0               agrigento       135
# 1             alessandria      3654
# 2                  ancona      1822
# 3                   aosta      1150
# 4                  arezzo       655
# 5           ascoli piceno       286
# 6                    asti      1655
# 7                avellino       474
# 8                    bari      1362
# 9                     bat       380
# 10                belluno      1142
# 11              benevento       189
# 12                bergamo     11622
# 13                 biella      1002
# 14                bologna      4685
# 15                bolzano      2552
# 16                brescia     13391
# 17               brindisi       600
# 18               cagliari       243
# 19          caltanissetta       162
# 20             campobasso       229
# 21                caserta       425
# 22                catania      1027
# 23              catanzaro       210
# 24                 chieti       767
# 25                   como      3440
# 26                cosenza       460
# 27                cremona      6178
# 28                crotone       118
# 29                  cuneo      2603
# 30                   enna       421
# 31                  fermo       454
# 32                ferrara       960
# 33                firenze      3275
# 34                 foggia      1098
# 35           forlì cesena      1651
# 36              frosinone       573
# 37                 genova      5007
# 38                gorizia       192
# 39               grosseto       416
# 40                imperia      1389
# 41                isernia        57
# 42               l'aquila       243
# 43              la spezia       871
# 44                 latina       507
# 45                  lecce       502
# 46                  lecco      2419
# 47                livorno       530
# 48                   lodi      3204
# 49                  lucca      1316
# 50               macerata      1050
# 51                mantova      3221
# 52          massa carrara      1021
# 53                 matera       202
# 54                messina       552
# 55                 milano     20893
# 56                 modena      3772
# 57          monza brianza      4974
# 58                 napoli      2506
# 59                 novara      2434
# 60                  nuoro        78
# 61               oristano        55
# 62                 padova      3885
# 63                palermo       523
# 64                  parma      3260
# 65                  pavia      4652
# 66                perugia       994
# 67                 pesaro      2630
# 68                pescara      1421
# 69               piacenza      4300
# 70                   pisa       863
# 71                pistoia       647
# 72              pordenone       648
# 73                potenza       181
# 74                  prato       535
# 75                 ragusa        94
# 76                ravenna       993
# 77        reggio calabria       260
# 78          reggio emilia      4812
# 79                  rieti       328
# 80                 rimini      2054
# 81                   roma      5117
# 82                 rovigo       429
# 83                salerno       664
# 84                sassari       854
# 85                 savona      1370
# 86                  siena       425
# 87               siracusa       235
# 88                sondrio      1266
# 89           sud sardegna        94
# 90                taranto       270
# 91                 teramo       641
# 92                  terni       359
# 93                 torino     14204
# 94                trapani       139
# 95                 trento      4283
# 96                treviso      2565
# 97                trieste      1300
# 98                  udine       967
# 99                 varese      3073
# 100               venezia      2568
# 101  verbano-cusio-ossola      1069
# 102              vercelli      1160
# 103                verona      4897
# 104         vibo valentia        75
# 105               vicenza      2743
# 106               viterbo       403
# 107                totale    215858

# %%
# this will replace the " /" with just a ",", as required by the instructions
inf_df3 = inf_df2.replace('bat','barletta-andria-trani')
inf_df3.head(40)
# Out:
#                  Province  Infected
# 0               agrigento       135
# 1             alessandria      3654
# 2                  ancona      1822
# 3                   aosta      1150
# 4                  arezzo       655
# 5           ascoli piceno       286
# 6                    asti      1655
# 7                avellino       474
# 8                    bari      1362
# 9   barletta-andria-trani       380
# 10                belluno      1142
# 11              benevento       189
# 12                bergamo     11622
# 13                 biella      1002
# 14                bologna      4685
# 15                bolzano      2552
# 16                brescia     13391
# 17               brindisi       600
# 18               cagliari       243
# 19          caltanissetta       162
# 20             campobasso       229
# 21                caserta       425
# 22                catania      1027
# 23              catanzaro       210
# 24                 chieti       767
# 25                   como      3440
# 26                cosenza       460
# 27                cremona      6178
# 28                crotone       118
# 29                  cuneo      2603
# 30                   enna       421
# 31                  fermo       454
# 32                ferrara       960
# 33                firenze      3275
# 34                 foggia      1098
# 35           forlì cesena      1651
# 36              frosinone       573
# 37                 genova      5007
# 38                gorizia       192
# 39               grosseto       416

# %%
df5 = pd.merge(inf_df3, df4, on='Province', how='inner')

# %%
df5.head(150)
# Out:
#                   Province  Infected Density  Population
# 0                agrigento       135     142      434870
# 1              alessandria      3654     118      421284
# 2                   ancona      1822     240      471228
# 3                    aosta      1150      39      125666
# 4                   arezzo       655     106      342654
# 5            ascoli piceno       286     169      207179
# 6                     asti      1655     142      214638
# 7                 avellino       474     149      418306
# 8                     bari      1362     326     1248489
# 9    barletta-andria-trani       380     253      390011
# 10                 belluno      1142      56      202950
# 11               benevento       189     133      277018
# 12                 bergamo     11622     405     1114590
# 13                  biella      1002     192      177585
# 14                 bologna      4685     274     1017196
# 15                 bolzano      2552      72      531178
# 16                 brescia     13391     265     1265954
# 17                brindisi       600     211      392975
# 18                cagliari       243     344      430372
# 19           caltanissetta       162     123      262458
# 20              campobasso       229      76      221238
# 21                 caserta       425     348      922965
# 22                 catania      1027     310     1103917
# 23               catanzaro       210     148      358316
# 24                  chieti       767     148      385588
# 25                    como      3440     468      599204
# 26                 cosenza       460     105      705753
# 27                 cremona      6178     203      358955
# 28                 crotone       118     101      174980
# 29                   cuneo      2603      85      587098
# 30                    enna       421      64      164788
# 31                   fermo       454     201      173800
# 32                 ferrara       960     131      345691
# 33                 firenze      3275     288     1012407
# 34                  foggia      1098      89      622183
# 35            forlì cesena      1651     166      394627
# 36               frosinone       573     151      489083
# 37                  genova      5007     455      837427
# 38                 gorizia       192     298      139403
# 39                grosseto       416      49      221629
# 40                 imperia      1389     185      213840
# 41                 isernia        57      55       84379
# 42                l'aquila       243      59      299031
# 43               la spezia       871     249      219556
# 44                  latina       507     255      575254
# 45                   lecce       502     284      795134
# 46                   lecco      2419     419      337380
# 47                 livorno       530     276      334832
# 48                    lodi      3204     294      230198
# 49                   lucca      1316     219      387876
# 50                macerata      1050     113      314178
# 51                 mantova      3221     176      412292
# 52           massa carrara      1021     169      194878
# 53                  matera       202      57      197909
# 54                 messina       552     191      622962
# 55                  milano     20893   2 071     3261873
# 56                  modena      3772     262      705393
# 57           monza brianza      4974    2156      873935
# 58                  napoli      2506   2 624     3072996
# 59                  novara      2434     275      369018
# 60                   nuoro        78      37      208550
# 61                oristano        55      53      157707
# 62                  padova      3885     437      937908
# 63                 palermo       523     249     1245826
# 64                   parma      3260     131      451631
# 65                   pavia      4652     184      545888
# 66                 perugia       994     104      656382
# 67                  pesaro      2630     140      358886
# 68                 pescara      1421     259      318909
# 69                piacenza      4300     111      287674
# 70                    pisa       863     171      419037
# 71                 pistoia       647     303      292473
# 72               pordenone       648     137      312533
# 73                 potenza       181      55      364960
# 74                   prato       535     705      257716
# 75                  ragusa        94     198      320893
# 76                 ravenna       993     209      389456
# 77         reggio calabria       260     171      544815
# 78           reggio emilia      4812     232      531891
# 79                   rieti       328      57      155503
# 80                  rimini      2054     392      339017
# 81                    roma      5117     810     4335849
# 82                  rovigo       429     129      234937
# 83                 salerno       664     222     1098513
# 84                 sassari       854      64      491571
# 85                  savona      1370     179      276064
# 86                   siena       425      70      267197
# 87                siracusa       235     188      399224
# 88                 sondrio      1266      57      181095
# 89            sud sardegna        94      54      350725
# 90                 taranto       270     234      576756
# 91                  teramo       641     158      308052
# 92                   terni       359     106      225633
# 93                  torino     14204     330     2256142
# 94                 trapani       139     174      430492
# 95                  trento      4283      87      541098
# 96                 treviso      2565     358      887806
# 97                 trieste      1300    1103      234493
# 98                   udine       967     106      528791
# 99                  varese      3073     743      890768
# 100                venezia      2568     346      852351
# 101   verbano-cusio-ossola      1069      70      157844
# 102               vercelli      1160      82      170911
# 103                 verona      4897     299      926497
# 104          vibo valentia        75     139      160073
# 105                vicenza      2743     317      862418
# 106                viterbo       403      88      317030
# 107                 totale    215858   19982    60359546

# %%
# !pip install geocoder
# Out:
# Collecting geocoder
#   Downloading https://files.pythonhosted.org/packages/4f/6b/13166c909ad2f2d76b929a4227c952630ebaf0d729f6317eb09cbceccbab/geocoder-1.38.1-py2.py3-none-any.whl (98kB)
#      |████████████████████████████████| 102kB 7.4MB/s ta 0:00:011
# Collecting ratelim (from geocoder)
#   Downloading https://files.pythonhosted.org/packages/f2/98/7e6d147fd16a10a5f821db6e25f192265d6ecca3d82957a4fdd592cad49c/ratelim-0.1.6-py2.py3-none-any.whl
# Requirement already satisfied: click in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (7.0)
# Requirement already satisfied: requests in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (2.21.0)
# Requirement already satisfied: future in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (0.17.1)
# Requirement already satisfied: six in /opt/conda/envs/Python36/lib/python3.6/site-packages (from geocoder) (1.12.0)
# Requirement already satisfied: decorator in /opt/conda/envs/Python36/lib/python3.6/site-packages (from ratelim->geocoder) (4.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (2020.4.5.1)
# Requirement already satisfied: idna<2.9,>=2.5 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /opt/conda/envs/Python36/lib/python3.6/site-packages (from requests->geocoder) (1.24.1)
# Installing collected packages: ratelim, geocoder
# Successfully installed geocoder-1.38.1 ratelim-0.1.6

# %%
from geopy.geocoders import Nominatim 
import geocoder

# %%
# define a function to get coordinates
def get_latlng(province):
    # initialize your variable to None
    lat_lng_coords = None
    # loop until you get the coordinates
    while(lat_lng_coords is None):
        g = geocoder.arcgis('{}, Italy'.format(province))
        lat_lng_coords = g.latlng
    return lat_lng_coords

# %%
coords = [ get_latlng(province) for province in df5["Province"].tolist() ]

# %%
coords
# Out:
# [[37.31087000000008, 13.576500000000067],
#  [44.90724000000006, 8.611560000000054],
#  [43.618490000000065, 13.508980000000065],
#  [45.73751000000004, 7.320720000000051],
#  [43.46354000000008, 11.877650000000074],
#  [42.853980000000035, 13.584410000000048],
#  [44.90443000000005, 8.199940000000026],
#  [40.91217000000006, 14.792880000000025],
#  [41.12587000000008, 16.866660000000024],
#  [41.17293777700007, 16.171158924000054],
#  [46.14098000000007, 12.212750000000028],
#  [41.129950000000065, 14.785520000000076],
#  [45.69523000000004, 9.66951000000006],
#  [45.56041000000005, 8.059780000000046],
#  [44.50484000000006, 11.345070000000021],
#  [46.49528000000004, 11.353460000000041],
#  [45.53689000000003, 10.232000000000028],
#  [40.634700000000066, 17.94025000000005],
#  [39.214540000000056, 9.110490000000027],
#  [37.49004000000008, 14.063220000000058],
#  [41.55913000000004, 14.656990000000064],
#  [41.07014000000004, 14.331610000000069],
#  [37.511360000000025, 15.067520000000059],
#  [38.91444000000007, 16.58436000000006],
#  [42.346640000000036, 14.165270000000078],
#  [45.81076000000007, 9.08710000000002],
#  [39.293130000000076, 16.257020000000068],
#  [45.14241000000004, 10.015210000000025],
#  [39.08125000000007, 17.122920000000022],
#  [44.38822000000005, 7.548330000000021],
#  [37.56499000000008, 14.27037000000007],
#  [43.16256000000004, 13.722080000000062],
#  [44.83839000000006, 11.619440000000054],
#  [43.78237000000007, 11.255010000000027],
#  [41.46217000000007, 15.544850000000054],
#  [44.03695546600005, 12.037581086000046],
#  [41.64092000000005, 13.350500000000068],
#  [44.41039000000006, 8.938980000000072],
#  [45.94146000000006, 13.62182000000007],
#  [42.76609000000008, 11.11725000000007],
#  [43.88985000000008, 8.038590000000056],
#  [41.59429000000006, 14.23273000000006],
#  [42.35397000000006, 13.394770000000051],
#  [44.10211000000004, 9.820060000000069],
#  [41.46273000000008, 12.905280000000062],
#  [40.35796000000005, 18.16802000000007],
#  [45.85166000000004, 9.39187000000004],
#  [43.552910000000054, 10.319980000000044],
#  [45.31200000000007, 9.497010000000046],
#  [43.841980000000035, 10.515310000000056],
#  [43.297660000000064, 13.45586000000003],
#  [45.165410000000065, 10.79242000000005],
#  [44.25503318600005, 10.010716510000066],
#  [40.667140000000074, 16.604450000000043],
#  [38.17837000000003, 15.553080000000023],
#  [45.46796000000006, 9.18178000000006],
#  [44.643230000000074, 10.93381000000005],
#  [45.59794782896939, 9.270323254892439],
#  [40.840140000000076, 14.252260000000035],
#  [45.44678000000005, 8.615240000000028],
#  [40.32036000000005, 9.330740000000048],
#  [39.906030000000044, 8.591320000000053],
#  [45.409440000000075, 11.871710000000064],
#  [38.122070000000065, 13.361120000000028],
#  [44.79853000000003, 10.340220000000045],
#  [45.19305000000003, 9.151300000000049],
#  [43.11136000000005, 12.383910000000071],
#  [43.91261000000003, 12.905610000000024],
#  [42.463910000000055, 14.213540000000023],
#  [45.05660000000006, 9.701760000000036],
#  [43.70996000000008, 10.399450000000058],
#  [43.938120000000026, 10.912580000000048],
#  [45.96493000000004, 12.644530000000032],
#  [40.637230000000045, 15.799290000000042],
#  [43.882070000000056, 11.100350000000049],
#  [36.92694000000006, 14.725400000000036],
#  [44.41176000000007, 12.204060000000027],
#  [38.11274000000003, 15.65175000000005],
#  [44.69559000000004, 10.64125000000007],
#  [42.398700000000076, 12.861620000000073],
#  [44.05542000000003, 12.570040000000063],
#  [41.90322000000003, 12.495650000000069],
#  [45.070160000000044, 11.789570000000026],
#  [40.67348000000004, 14.771250000000066],
#  [40.72705000000008, 8.553830000000062],
#  [44.30582000000004, 8.483640000000037],
#  [43.32563000000005, 11.330390000000023],
#  [37.07801000000006, 15.281330000000025],
#  [46.168030000000044, 9.872510000000034],
#  [39.428596965000054, 8.945278163000069],
#  [40.465370000000064, 17.250540000000058],
#  [42.657560000000046, 13.69736000000006],
#  [42.562830000000076, 12.64220000000006],
#  [45.06235000000004, 7.67993000000007],
#  [38.01874000000004, 12.514580000000024],
#  [46.07005000000004, 11.119260000000054],
#  [45.666360000000054, 12.241890000000069],
#  [45.65757000000008, 13.772690000000068],
#  [46.06452000000007, 13.23807000000005],
#  [45.81475000000006, 8.830130000000054],
#  [45.43811000000005, 12.31815000000006],
#  [46.09489049500007, 8.332695554000054],
#  [45.322640000000035, 8.418430000000058],
#  [45.43831000000006, 10.991710000000069],
#  [38.67602000000005, 16.094730000000027],
#  [45.54800000000006, 11.549470000000042],
#  [42.42094000000003, 12.10982000000007],
#  [46.25000000000006, 10.583330000000046]]

# %%
len(coords)
# Out:
# 108

# %%
df_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])
df5['Latitude'] = df_coords['Latitude']
df5['Longitude'] = df_coords['Longitude']
df5.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b55af8cacdc1> in <module>
# ----> 1 df_coords = pd.DataFrame(coords, columns=['Latitude', 'Longitude'])
#       2 df5['Latitude'] = df_coords['Latitude']
#       3 df5['Longitude'] = df_coords['Longitude']
#       4 df5.head()
#
# NameError: name 'pd' is not defined

# %%
# The code was removed by Watson Studio for sharing.
# Out:
# Your credentails:
# CLIENT_ID: Q1KDITMHCYKL0FVUOCBAYFDNQZNEB3XFPA2O3DIHUWOQBUEF
# CLIENT_SECRET:ODJCV2R4CIYTIXPWOTZZXDCTJ4YQ2AFTJSE0USAJVLESLX1S
